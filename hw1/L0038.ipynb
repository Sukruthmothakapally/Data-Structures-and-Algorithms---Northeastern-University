# %%
############################################################
# Solution.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2020
###########################################################
class Solution:
    def __init__(self):
        pass

  #THIS IS LEETCODE
    def  countAndSay(self,n:'int')->'string':
    ## NOTHING CAN BE CHANGED HERE
        return self._alg_integer(n)

    def  countAndSayString(self,n:'string')->'string':
    #Nothing can be changed here
        return self._alg_string(n) 

  ### YOU CAN HAVE ANY NUMBER OF FUNCTIONS AND CLASSES BELOW


  ## n is str here
    def _alg_string(self,n:'string')->'string':
        print("WRITE CODE BELOW")

        #create 2 variables, that can be used as string index and increments over time 
        #starting from 1st and 2nd element of the string
        l=0
        r=1
        #let count be 1 since minimum count of a number is 1
        count=1
        #create an empty string to store the result
        res=""

        #iterate over the while loop until 'r' is greater than the length of n. 
        while(r<=len(n)):

            #if r is lesser than the length of n and element of n in position l is equal to r's position ->
            #increment count by 1
            #increment l and r by 1
            #reason - > if both elements are same, count is increased. Then l and r are moved by 1 step
            if r <=len(n) - 1 and n[l]==n[r]:
                count+=1
                l+=1
                r+=1

            #else -> now oth are elements are different. So concatenate count and value in l position to res
            #then, move l and r by 1 step. 
            #reset count value to 1_alg
            #reason -> since both the elements are now different, we need to add the count of previous element to result string
            else:
                res+=str(count)+n[l]
                l+=1
                r+=1
                count = 1

        #return the result string
        return res
        
  ## n is int here
    def _alg_integer(self,n:'int')->'string':
        print("WRITE CODE BELOW")
        s="1"
        for _ in range(1,n):
            s=self._alg_string(s)
        return s

# %% [markdown]
# # YOU CANNOT CHANGE ANYTHING BELOW

# %%
############################################################
# LookAndSay.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2020
###########################################################

############################################################
# NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################


class LookAndSay():
    def __init__(self):
        self._testBench()
        
    def _look_and_say_integer(self,n:'int')->'string':
        s = Solution()
        return s.countAndSay(n) #implement in solution

    def _look_and_say_string(self,n:'string')->'string': 
        s = Solution()
        return s.countAndSayString(n) #implement in solution

  #private function
    def _testBench(self):
        self._tests()
        self._testn()
        print("ALL TESTS PASSED")
     

  #Private function
    def _tests(self):
        n = "123" 
        e = "111213" 
        s = self._look_and_say_string(n) 
        assert(s == e);

        n = "9999999999" 
        e = "109" 
        s = self._look_and_say_string(n) 
        assert(s == e);

        n = "9876543210" 
        e = "19181716151413121110" 
        s = self._look_and_say_string(n) 
        assert(s == e);

  #Private function
    def _testn(self):
        n = 1 
        e = "1" 
        s = self._look_and_say_integer(n) 
        assert(s == e);

        n = 2 
        e = "11" 
        s = self._look_and_say_integer(n) 
        assert(s == e);

        n = 3
        e = "21" 
        s = self._look_and_say_integer(n) 
        assert(s == e);

        n = 4 
        e = "1211" 
        s = self._look_and_say_integer(n) 
        assert(s == e);

        n = 5
        e = "111221" 
        s = self._look_and_say_integer(n) 
        assert(s == e);

        for n in range(1,32):
            s = self._look_and_say_integer(n)
            print("n = ",n, " Length = ", len(s))
            print("n = ",n," ",s)

############################################################
# main 
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
      t = LookAndSay()
############################################################
# start up
###########################################################
if (__name__  == '__main__'):
      main()
# Out:
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  1  Length =  1
# n =  1   1
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  2  Length =  2
# n =  2   11
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  3  Length =  2
# n =  3   21
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  4  Length =  4
# n =  4   1211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  5  Length =  6
# n =  5   111221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  6  Length =  6
# n =  6   312211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  7  Length =  8
# n =  7   13112221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  8  Length =  10
# n =  8   1113213211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  9  Length =  14
# n =  9   31131211131221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  10  Length =  20
# n =  10   13211311123113112211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  11  Length =  26
# n =  11   11131221133112132113212221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  12  Length =  34
# n =  12   3113112221232112111312211312113211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  13  Length =  46
# n =  13   1321132132111213122112311311222113111221131221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  14  Length =  62
# n =  14   11131221131211131231121113112221121321132132211331222113112211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  15  Length =  78
# n =  15   311311222113111231131112132112311321322112111312211312111322212311322113212221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  16  Length =  102
# n =  16   132113213221133112132113311211131221121321131211132221123113112221131112311332111213211322211312113211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  17  Length =  134
# n =  17   11131221131211132221232112111312212321123113112221121113122113111231133221121321132132211331121321231231121113122113322113111221131221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  18  Length =  176
# n =  18   31131122211311123113321112131221123113112211121312211213211321322112311311222113311213212322211211131221131211132221232112111312111213111213211231131122212322211331222113112211
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  19  Length =  226
# n =  19   1321132132211331121321231231121113112221121321132122311211131122211211131221131211132221121321132132212321121113121112133221123113112221131112311332111213122112311311123112111331121113122112132113213211121332212311322113212221
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  20  Length =  302
# n =  20   
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  21  Length =  408
# n =  21   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  22  Length =  528
# n =  22   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  23  Length =  678
# n =  23   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  24  Length =  904
# n =  24   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  25  Length =  1182
# n =  25   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  26  Length =  1540
# n =  26   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  27  Length =  2012
# n =  27   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  28  Length =  2606
# n =  28   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  29  Length =  3410
# n =  29   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  30  Length =  4462
# n =  30   ...
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# WRITE CODE BELOW
# n =  31  Length =  5808
# n =  31   ...
# ALL TESTS PASSED
